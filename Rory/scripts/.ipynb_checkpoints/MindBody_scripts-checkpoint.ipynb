# %% [markdown]
# # Clean and plot MindBody data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from datetime import datetime

# %%
df1 = pd.read_csv("mindbody_twitter_scores_monday.csv")
df2 = pd.read_csv("mindbody_twitter_scores_tuesday.csv")

# %%
df1 = df1.rename(columns={"0": 'created_at', "1": "tweet"})
df2 = df2.rename(columns={"0": 'created_at', "1": "tweet"})

# %%
df = df1.append(df2, ignore_index=True)
df
# Out:
#                 created_at                                              tweet  \
# 0      2018-06-19 02:56:50  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 1      2018-06-19 02:56:32  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 2      2018-06-19 02:55:43  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 3      2018-06-19 02:54:54  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 4      2018-06-19 02:54:36  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 5      2018-06-19 02:54:17  b'RT @lilyabner97: Benefits of Gratitude .. #M...
# 6      2018-06-19 02:54:12  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 7      2018-06-19 02:54:09  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 8      2018-06-19 02:53:38  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 9      2018-06-19 02:53:19  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 10     2018-06-19 02:53:04  b'Benefits of Gratitude .. #MindBodySoul #Mind...
# 11     2018-06-19 02:52:58  b'Benefits of Gratitude .. #MindBodySoul #Mind...
# 12     2018-06-19 02:51:09  b'RT @HealingMB: Those who... Those who.. #Zen...
# 13     2018-06-19 02:41:30  b'RT @HealingMB: Silence had a mysterious calm...
# 14     2018-06-19 02:40:56  b'RT @BethFratesMD: Hoping you find the right ...
# 15     2018-06-19 02:39:02  b'RT @HealingMB: Silence had a mysterious calm...
# 16     2018-06-19 02:35:51  b'RT @hifunctionorg: THE  MIND  PARADOX -\n#mi...
# 17     2018-06-19 02:33:48  b'RT @HealingMB: Silence had a mysterious calm...
# 18     2018-06-19 02:33:40  b'Love brain research?  #brainresearch\xc2\xa0...
# 19     2018-06-19 02:31:44  b'RT @HealingMB: Your silence hurts me more .....
# 20     2018-06-19 02:28:07  b'RT @HealingMB: Perspective is Everything #Mi...
# 21     2018-06-19 02:25:19  b'RT @SChasse49: Massage for Text Neck\n\xe2\x...
# 22     2018-06-19 02:24:03  b'RT @BethFratesMD: "Seize from every moment i...
# 23     2018-06-19 02:23:26  b'RT @BethFratesMD: "Seize from every moment i...
# 24     2018-06-19 02:21:22  b'RT @BethFratesMD: Hoping you find the right ...
# 25     2018-06-19 02:19:20  b'RT @BethFratesMD: "Seize the moments of happ...
# 26     2018-06-19 02:17:39  b'RT @BethFratesMD: "Seize from every moment i...
# 27     2018-06-19 02:17:03  b'RT @HealingMB: Always remember the best is t...
# 28     2018-06-19 02:16:01  b'RT @BethFratesMD: "In all things of nature t...
# 29     2018-06-19 02:15:54  b'RT @BethFratesMD: Hoping you find the right ...
# ...                    ...                                                ...
# 15881  2018-06-12 18:30:04  b'RT @BethFratesMD: Nature soothes the soul.\n...
# 15882  2018-06-12 18:29:46  b'RT @HealingMB: Remember, that you are the so...
# 15883  2018-06-12 18:27:40  b'RT @HealingMB: The most dangerous person in ...
# 15884  2018-06-12 18:26:13  b'RT @HealingMB: The most dangerous person in ...
# 15885  2018-06-12 18:20:11  b'RT @HealingMB: If there ever comes a day .. ...
# 15886  2018-06-12 18:20:01  b'RT @HealingMB: Criticism is something you ca...
# 15156  2018-06-13 05:34:26  b'Just one of nine impressive weight loss succ...
# 15873  2018-06-12 18:43:24  b"Is the #KetogenicDiet the 'Secret Weapon' yo...
#
#        compound  positive  negative  neutral
# 0        0.7096     0.396     0.000    0.604
# 5        0.7096     0.371     0.000    0.629
# 10       0.5106     0.268     0.000    0.732
# 11       0.5106     0.292     0.000    0.708
# 12       0.0000     0.000     0.000    1.000
# 13       0.4019     0.184     0.000    0.816
# 14       0.7650     0.223     0.000    0.777
# 16      -0.2808     0.000     0.141    0.859
# 18       0.0000     0.000     0.000    1.000
# 19      -0.4767     0.000     0.220    0.780
# 20       0.0000     0.000     0.000    1.000
# 21       0.0000     0.000     0.000    1.000
# 22       0.0000     0.000     0.000    1.000
# 25       0.9184     0.333     0.000    0.667
# 27       0.6369     0.231     0.000    0.769
# 28       0.0000     0.000     0.000    1.000
# 30       0.0000     0.000     0.000    1.000
# 31       0.8065     0.414     0.074    0.512
# 33       0.5859     0.147     0.000    0.853
# 34       0.0000     0.000     0.000    1.000
# 36      -0.3102     0.087     0.172    0.740
# 37       0.0000     0.000     0.000    1.000
# 39      -0.2808     0.000     0.162    0.838
# 40       0.0000     0.000     0.000    1.000
# 45       0.3400     0.247     0.153    0.600
# 48       0.0000     0.000     0.000    1.000
# 50       0.7650     0.258     0.000    0.742
# 53       0.0000     0.000     0.000    1.000
# 54       0.8625     0.407     0.000    0.593
# 57       0.3400     0.206     0.128    0.667
# ...         ...       ...       ...      ...
# 9572     0.3400     0.247     0.153    0.600
# 9715     0.4404     0.139     0.000    0.861
# 9831    -0.2732     0.083     0.180    0.737
# 9979     0.0000     0.000     0.000    1.000
# 10012    0.0516     0.120     0.111    0.769
# 10094    0.5256     0.175     0.000    0.825
# 11400    0.3400     0.218     0.135    0.647
# 11620    0.3400     0.206     0.128    0.667
# 11676   -0.3102     0.073     0.144    0.784
# 11677   -0.3102     0.087     0.172    0.740
# 11723   -0.3134     0.087     0.173    0.739
# 12312    0.3400     0.218     0.135    0.647
# 12877    0.9274     0.430     0.000    0.570
# 12955    0.3612     0.106     0.000    0.894
# 12976    0.3612     0.102     0.000    0.898
# 13006   -0.1280     0.089     0.110    0.802
# 13047   -0.3818     0.000     0.133    0.867
# 13256    0.3400     0.264     0.164    0.571
# 13718    0.4019     0.109     0.000    0.891
# 13932    0.4019     0.119     0.000    0.881
# 13944    0.0000     0.000     0.000    1.000
# 13994    0.5256     0.175     0.000    0.825
# 14008   -0.3102     0.094     0.185    0.721
# 14034    0.0000     0.000     0.000    1.000
# 14112    0.4754     0.119     0.000    0.881
# 14373    0.6597     0.213     0.000    0.787
# 14387   -0.3102     0.094     0.185    0.721
# 14605    0.3400     0.231     0.144    0.625
# 15156    0.6908     0.314     0.103    0.583
# 15873   -0.5859     0.000     0.194    0.806
#
# [1393 rows x 6 columns]

# %%
df['created_at'] = df['created_at'].map(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
# Out:
# C:\Users\RoryLukins\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["date"] = df['created_at'].map(lambda x: datetime.date(x))
df["time"] = df['created_at'].map(lambda x: datetime.time(x))
df["hour"] = df['time'].map(lambda x: x.hour)
df['day'] = df['date'].map(lambda x: x.day)
df.head()
# Out:
# C:\Users\RoryLukins\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\RoryLukins\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\RoryLukins\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\RoryLukins\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#             created_at                                              tweet  \
# 0  2018-06-19 02:56:50  b'RT @HealingMB: Benefits of Gratitude .. #Min...
# 5  2018-06-19 02:54:17  b'RT @lilyabner97: Benefits of Gratitude .. #M...
# 10 2018-06-19 02:53:04  b'Benefits of Gratitude .. #MindBodySoul #Mind...
# 11 2018-06-19 02:52:58  b'Benefits of Gratitude .. #MindBodySoul #Mind...
# 12 2018-06-19 02:51:09  b'RT @HealingMB: Those who... Those who.. #Zen...
#
#     compound  positive  negative  neutral        date      time  hour  day
# 0     0.7096     0.396       0.0    0.604  2018-06-19  02:56:50     2   19
# 5     0.7096     0.371       0.0    0.629  2018-06-19  02:54:17     2   19
# 10    0.5106     0.268       0.0    0.732  2018-06-19  02:53:04     2   19
# 11    0.5106     0.292       0.0    0.708  2018-06-19  02:52:58     2   19
# 12    0.0000     0.000       0.0    1.000  2018-06-19  02:51:09     2   19

# %%
monday = df[df["day"] == 18]
tuesday = df[df["day"] == 19]
friday = df[df["day"] == 15]

# %%
friday_means = friday.groupby(friday['hour']).mean()
friday_means = friday_means.reset_index()

# %%
# Plot Friday's tweet polarity
plt.plot(friday_means['hour'], friday_means['compound'])
#plt.plot(friday_means['hour'], friday_means['positive'], color='r')
#plt.plot(friday_means['hour'], friday_means['negative'], color='g')
plt.ylim(-0.5,0.5)
plt.xlim(0,24)
plt.hlines(0, 0, 24)
plt.axvline(9, 1, -1, c='aquamarine', linestyle='dashed')
plt.axvline(16, 1, -1, c='aquamarine', linestyle='dashed')
plt.title("Compound Sentiment of #MindBody Tweets\nFriday, June 15")
plt.xlabel("Hours")
plt.ylabel("Tweet Polarity")

plt.savefig('MB_polarity_friday.png')

# %%
# plot Monday's tweet polarity

#create grouped dataframes
monday_means = monday.groupby(monday['hour']).mean()
monday_means = monday_means.reset_index()

plt.plot(monday_means['hour'], monday_means['compound'])
plt.ylim(-0.5,0.5)
plt.xlim(0,24)
plt.hlines(0, 0, 24)
plt.axvline(9, 1, -1, c='aquamarine', linestyle='dashed')
plt.axvline(16, 1, -1, c='aquamarine', linestyle='dashed')
plt.title("Compound Sentiment of #MindBody Tweets\nMonday, June 18")
plt.xlabel("Hours")
plt.ylabel("Tweet Polarity")

plt.savefig('MB_polarity_monday.png')

# %%
# plot Tuesday's tweet polarity

#create grouped dataframes
tuesday_means = tuesday.groupby(tuesday['hour']).mean()
tuesday_means = tuesday_means.reset_index()

plt.plot(tuesday_means['hour'], tuesday_means['compound'])
plt.ylim(-0.4,0.7)
plt.xlim(0,24)
plt.hlines(0, 0, 24)
plt.axvline(9, 1, -1, c='aquamarine', linestyle='dashed')
plt.axvline(16, 1, -1, c='aquamarine', linestyle='dashed')
plt.title("Compound Sentiment of #MindBody Tweets\nTuesday, June 19")
plt.xlabel("Hours")
plt.ylabel("Tweet Polarity")

plt.savefig('MB_polarity_tuesday.png')
