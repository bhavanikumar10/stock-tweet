# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Importing Dependencies
import pandas as pd
import json
import tweepy
import matplotlib.pyplot as plt
import numpy as np 
from  datetime import datetime
import csv
from config import consumer_key, consumer_secret, access_token, access_token_secret
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
# Twitter Credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
search_term = "$fb"

# %%
# Open/Create a file to append data
csvFile = open('facebook_cashtags_tweets.csv', 'w')

# %%
#Use csv Writer
csvWriter = csv.writer(csvFile)

# %%
for tweet in tweepy.Cursor(api.search,q=search_term, lang="en").items(10000):
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2018-06-21 00:45:05 REAL TIME TRADE ALERTS via PRIVATE $TWTR FEED, perfect for people who have FT jobs and trade part-time! $AMZN $NFLX $GOOGL $BABA $JPM $FB
# 2018-06-21 00:43:53 RT @charliebilello: Your market recap...
# $FB: All-Time High
# $AMZN: All-Time High
# $NFLX: All-Time High
# $GOOGL: All-Time High
# The Band i…
# 2018-06-21 00:43:42 RT @CNBCFastMoney: FANG stocks are out of control! $FB $AMZN $NFLX and $GOOGL hitting new all-time highs today and up double digits in the…
# 2018-06-21 00:43:17 RT @DataTrekMB: Check out @JeffCoxCNBCcom latest article for @CNBC, including why @DataTrekMB's Nick Colas thinks $AMZN, $GOOG and $FB may…
# 2018-06-21 00:42:31 RT @charliebilello: Your market recap...
# $FB: All-Time High
# $AMZN: All-Time High
# $NFLX: All-Time High
# $GOOGL: All-Time High
# The Band i…
# 2018-06-21 00:42:06 MAXIMIZE PROFIT! CHAT WITH TRADERS ON OUR MARKET FOCUSED CHAT ROOM AT https://t.co/35LuLR0k4f $NFLX $FB $MSFT
# ...

# %%
analyzer = SentimentIntensityAnalyzer()
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# %%
for tweet in df[1]:
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet)
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
    # Add each value to the appropriate list
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)
    
# df['compound'] = compound_list
# df['positive'] = positive_list
# df['negative'] = negative_list
# df['neutral'] = neutral_list

# df.to_csv('facebook_cashtags_tweets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-700be6152eae> in <module>()
# ----> 1 for tweet in df[1]:
#       2     # Run Vader Analysis on each tweet
#       3     results = analyzer.polarity_scores(tweet)
#       4     compound = results["compound"]
#       5     pos = results["pos"]
#
# NameError: name 'df' is not defined

# %%
# Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet)
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]

# %%
 # Add each value to the appropriate list
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)

# %%
df['compound'] = compound_list
df['positive'] = positive_list
df['negative'] = negative_list
df['neutral'] = neutral_list

df.to_csv('facebook_cashtags_tweets.csv', index=False)

# %%
fn = 'facebook_cashtags_tweets.csv'
df2 = pd.read_csv(fn)
df2.dropna(inplace=True)
df2.info()

# %%
df2['Dates'] = pd.to_datetime(df2['Dates'])
df2.dtypes

# %%
df2['Hour'] = df2['Dates'].dt.hour

# %%
df2['Day'] = df2['Dates'].dt.day

# %%
df2.iloc[[50,51,52]]

# %%
# groupby example for col Count
new_series = df2.groupby('Hour').mean()

# %%
fb_19 = 'facebook_cashtags_tweets.csv'

# %%
fb_19_df = pd.read_csv(fb_19)

# %%
fb_19_df

# %%
for tweet in fb_19_df["b'$FB : 74c05c7a-39f8-4dfa-820a-9bbc9d825692'"]:
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet)
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
    # Add each value to the appropriate list
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)

# %%
fb_19_df['compound'] = compound_list
fb_19_df['positive'] = positive_list
fb_19_df['negative'] = negative_list
fb_19_df['neutral'] = neutral_list

# %%
converted_timestamps = []
for raw in fb_19_df['2018-06-20 02:15:32']:
    # https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
    # http://strftime.org/
    converted_time = datetime.strptime(raw, "%a %b %d %H:%M:%S %z %Y")
    converted_timestamps.append(converted_time)

# %%
day = []
for x in range(len(converted_timestamps)):
    days = converted_timestamps[x].day
    day.append(days)

# %%
hour = []
for x in range(len(converted_timestamps)):
    hours = converted_timestamps[x].hour
    hour.append(hours)

# %%
# groupby example for col Count
new_series = df2.groupby('Hour').mean()
